# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\dell\Desktop\HousePricePrediction\Dataset\house_data.csv.csv")

print(df.head())
print(df.columns)
# Out:
#    House_ID       City Locality_Tier  BHK  Bathrooms  Super_Area_sqft  \
# 0         1  Hyderabad           Mid    3          4            957.3
# 1         2  Bangalore        Budget    2          3            883.3
# 2         3       Pune       Premium    3          4           1331.5
# 3         4     Mumbai       Premium    3          4            997.6
# 4         5       Pune           Mid    2          2            967.6
#
#    Carpet_Area_sqft  Floor_No  Total_Floors  Property_Age_years  ...  \
# 0             809.1        11            15                   8  ...
# 1             711.7        13            16                  13  ...
# 2            1087.1        13            15                   7  ...
# 3             801.0         7            19                  10  ...
# 4             707.6         5            16                   6  ...
#
#        Furnishing Lift  Gated_Society  Distance_to_Metro_km  \
# 0  Semi-Furnished    1              0                  2.44
# ...

# %%
x=df[['Super_Area_sqft','BHK','Bathrooms']]
y=df['Market_Price_INR']

# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\dell\Desktop\HousePricePrediction\Dataset\house_data.csv.csv")

# Select required columns
df = df[['House_ID',
         'Super_Area_sqft',
         'Bathrooms',
         'Furnishing',
         'Price_per_sqft_INR',
         'Market_Price_INR']]

print(df.head())
# Out:
#    House_ID  Super_Area_sqft  Bathrooms      Furnishing  Price_per_sqft_INR  \
# 0         1            957.3          4  Semi-Furnished                8082
# 1         2            883.3          3  Semi-Furnished                6534
# 2         3           1331.5          4     Unfurnished               11031
# 3         4            997.6          4  Semi-Furnished               19140
# 4         5            967.6          2     Unfurnished                7847
#
#    Market_Price_INR
# 0           7736451
# 1           5771877
# 2          14688106
# 3          19094254
# 4           7592420

# %%
X = df[['House_ID',
       'Super_Area_sqft',
        'Bathrooms',
        'Furnishing',
        'Price_per_sqft_INR']]

y = df['Market_Price_INR']

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
df['Furnishing'] = le.fit_transform(df['Furnishing'])

# %%
print(df.info())
print(df.isnull().sum())
print(df.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12000 entries, 0 to 11999
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   House_ID            12000 non-null  int64
#  1   Super_Area_sqft     12000 non-null  float64
#  2   Bathrooms           12000 non-null  int64
#  3   Furnishing          12000 non-null  int64
#  4   Price_per_sqft_INR  12000 non-null  int64
#  5   Market_Price_INR    12000 non-null  int64
# dtypes: float64(1), int64(5)
# memory usage: 562.6 KB
# None
# House_ID              0
# Super_Area_sqft       0
# Bathrooms             0
# Furnishing            0
# Price_per_sqft_INR    0
# Market_Price_INR      0
# dtype: int64
#           House_ID  Super_Area_sqft     Bathrooms   Furnishing  \
# count  12000.00000     12000.000000  12000.000000  12000.00000
# mean    6000.50000      1018.260342      2.536083      1.15825
# ...

# %%
df.dropna(inplace=True)
