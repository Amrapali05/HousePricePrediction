# %%
import pickle
pickle.dump(model,open("house_model.pkl","wb"))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 import pickle
# ----> 2 pickle.dump(model,open("house_model.pkl","wb"))
#
# NameError: name 'model' is not defined
